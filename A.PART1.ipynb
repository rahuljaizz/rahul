# %% [raw]
# 1.  In the below elements which of them are values or an expression? eg:- values can be
#     integer or string and expressions will be mathematical operators.
#
# *  multiplication operator. muliplies values
#
# 'hello'   string
#
# -87.8      negative float
#
# -     subtraction operator. subtracts one value from another
#
# /     Division  operator
#
# +     addition operator. adds two values
#
# 6     integer
#
#
# 2. What is the difference between string and variable?
#
# ans -A string represents a group of characters. For eg. the names of persons, their addresses,
#      vehical number, card number ,  etc.
#
#       a variable is imagined as a storage box which can store some value .
#       for eg. a = 1
#
#
# 3. Describe three different data types.
#
# ans - 1-None Type.
#          the "None Type " data type represents an object that does not contain any value.
#
#       2-Numeric Type.
#           the numeric types represents numbers. There are three sub types.
#            1-int         eg. a=23
#            2-float        eg. d= 64.6
#            3-complex       eg.  c= 2.5 + 2.5j
#
#       3-Sets
#           a set is an unordered  collection of elements much like a set in mathematics. sets does
#           not duplicate elements. and the order of elements is  not maintained in the sets.
#
# 4.What is an expression made up of? What do all expressions do?
# ans
#      An expression is a combination of operators, constants and variables. An expression may          consist of one or more operands, and zero or more operators to produce a value.
#      AND expression  produces some value or result after being interpreted by the Python              interpreter.
#
#
# 5.This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
# ans.
#      spam = 10" is a statement. It assigns the value 10 to the variable named "spam." The               expression on the right side of the assignment operator (=) is the value 10,
#      and the statement as a whole assigns that value to the variable.
#
#
# 6.After running the following code, what does the variable bacon contain?
#       bacon = 22
#       bacon + 1
# ans.   After running the code bacon = 22 and bacon + 1, the variable bacon would still contain          the value 22. Beacuse  The expression bacon + 1 is not assigned to any variable.
#
#
# 7.What should the values of the following two terms be?
# ans.
#    the value of the expression "spam" + "spamspam" is "spamspamspam".
#    AND the value of the expression "spam" * 3 is "spamspamspam".
#
#
# 8.Why is eggs a valid variable name while 100 is invalid?
# ans.
#     In most programming languages, including Python, variable names must adhere to certain rules     and conventions.
#     Variable names typically consist of letters (bott lowercase and uppercase), digits (0-9), and     undescores (_). They cannot start with a digit.
#
# 9. What three functions can be used to get the integer, floating-point number, or string
#    version of a value?
# ans.
#     1-int(): This function can be used to convert a value to an integer.
#     2-float(): This function is used to convert a value to a floating-point number.
#     3-str(): This function converts a value to its string representation. It takes any value,                  such as an integer, float, or even an object , and returns a string representation                of that value.
#
# 10.Why does this expression cause an error? How can you fix it?
# ans
#      The expression 'I have eaten' + 99 + ' burritos.' causes an error because it's trying to c         concatenate a string ('I have eaten') with an integer (99) directly.
#      To fix this, you can convert the integer into a string before concatenating it with the          other strings. Here's the corrected expression:
#
#       'I have eaten ' + str(99) + ' burritos.'
